# %%
# Run this if you update the populator.
import importlib
importlib.reload(populator);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-81bb04b2d64e> in <module>()
#       1 # Run this if you update the populator.
#       2 import importlib
# ----> 3 importlib.reload(populator);
#
# NameError: name 'populator' is not defined

# %%
import sys 
sys.path.append('..')

# %%
import populator

# %%
data_dir = 'data'
# Second item in tuple is max batch size for requests.
exchanges = [('binance', 1000)]
tick_size = '1m'

# %%
populator.grab_all_pairs(data_dir, exchanges, tick_size)
# Out:
# 946684800000
# Downloading price history for AE/BNB on exchange binance.
# 946684800000 10097178 60000
# Batch Size: 1000
# Total Entries: 10097178
# Note: Entries will not exist if they predate exchange history.
# Entries Processed: 9525010
# Entries Processed: 9526025
# Entries Processed: 9527025
# Entries Processed: 9528060
# Entries Processed: 9529060
# Entries Processed: 9530060
# Entries Processed: 9531060
# Entries Processed: 9532060
# Entries Processed: 9533060
# Entries Processed: 9534060
# Entries Processed: 9535060
# Entries Processed: 9536060
# Entries Processed: 9537060
# Entries Processed: 9538060
# Entries Processed: 9539060
# Entries Processed: 9540060
# Entries Processed: 9541060
# Entries Processed: 9542060
# Entries Processed: 9543060
# Entries Processed: 9544060
# Entries Processed: 9545060
# Entries Processed: 9546060
# Entries Processed: 9547060
# Entries Processed: 9548060
# Entries Processed: 9549060
# Entries Processed: 9550060
# Entries Processed: 9551060
# Entries Processed: 9552060
# Entries Processed: 9553060
# Entries Processed: 9554060
# Entries Processed: 9555060
# Entries Processed: 9556060
# Entries Processed: 9557060
# Entries Processed: 9558060
# Entries Processed: 9559060
# Entries Processed: 9560060
# Entries Processed: 9561060
# Entries Processed: 9562060
# Entries Processed: 9563060
# Entries Processed: 9564060
# Entries Processed: 9565060
# Entries Processed: 9566060
# Entries Processed: 9567060
# Entries Processed: 9568060
# Entries Processed: 9569060
# Entries Processed: 9570060
# Entries Processed: 9571060
# Entries Processed: 9572060
# Entries Processed: 9573060
# Entries Processed: 9574060
# Entries Processed: 9575060
# Entries Processed: 9576060
# Entries Processed: 9577060
# Entries Processed: 9578060
# Entries Processed: 9579060
# Entries Processed: 9580060
# Entries Processed: 9581060
# Entries Processed: 9582060
# Entries Processed: 9583060
# Entries Processed: 9584060
# Entries Processed: 9585060
# Entries Processed: 9586060
# Entries Processed: 9587060
# Entries Processed: 9588060
# Entries Processed: 9589060
# Entries Processed: 9590060
# Entries Processed: 9591060
# Entries Processed: 9592060
# Entries Processed: 9593060
# Entries Processed: 9594060
# Entries Processed: 9595060
# Entries Processed: 9596060
# Entries Processed: 9597060
# Entries Processed: 9598060
# Entries Processed: 9599060
# Entries Processed: 9600060
# Entries Processed: 9601060
# Entries Processed: 9602060
# Entries Processed: 9603060
# Entries Processed: 9604060
# Entries Processed: 9605060
# Entries Processed: 9606060
# Entries Processed: 9607060
# Entries Processed: 9608060
# Entries Processed: 9609060
# Entries Processed: 9610060
# Entries Processed: 9611060
# Entries Processed: 9612060
# Entries Processed: 9613060
# Entries Processed: 9614060
# Entries Processed: 9615060
# Entries Processed: 9616060
# Entries Processed: 9617060
# Entries Processed: 9618060
# Entries Processed: 9619060
# Entries Processed: 9620060
# Entries Processed: 9621060
# Entries Processed: 9866222
# Entries Processed: 9867222
# Entries Processed: 9868222
# Entries Processed: 9869222
# Entries Processed: 9870222
# Entries Processed: 9871222
# Entries Processed: 9872222
# Entries Processed: 9873222
# Entries Processed: 9874222
# Entries Processed: 9875222
# Entries Processed: 9876222
# Entries Processed: 9877222
# Entries Processed: 9878222
# Entries Processed: 9879222
# Entries Processed: 9880222
# Entries Processed: 9881222
# Entries Processed: 9882222
# Entries Processed: 9883222
# Entries Processed: 9884222
# Entries Processed: 9885222
# Entries Processed: 9886222
# Entries Processed: 9887222
# Entries Processed: 9888432
# Entries Processed: 9889432
# Entries Processed: 9890432
# Entries Processed: 9891432
# Entries Processed: 9892432
# Entries Processed: 9893432
# Entries Processed: 9894432
# Entries Processed: 9895432
# Entries Processed: 9896432
# Entries Processed: 9897432
# Entries Processed: 9898432
# Entries Processed: 9899432
# Entries Processed: 9900432
# Entries Processed: 9901432
# Entries Processed: 9902432
# Entries Processed: 9903432
# Entries Processed: 9904432
# Entries Processed: 9905432
# Entries Processed: 9906432
# Entries Processed: 9907432
# Entries Processed: 9908432
# Entries Processed: 9909432
# Entries Processed: 9910432
# Entries Processed: 9911432
# Entries Processed: 9912432
# Entries Processed: 9913432
# Entries Processed: 9914432
# Entries Processed: 9915432
# Entries Processed: 9916432
# Entries Processed: 9917432
# Entries Processed: 9918432
# Entries Processed: 9919432
# Entries Processed: 9920432
# Entries Processed: 9921432
# Entries Processed: 9922432
# Entries Processed: 9923432
# Entries Processed: 9924432
# Entries Processed: 9925852
# Entries Processed: 9926852
# Entries Processed: 9927852
# Entries Processed: 9928852
# Entries Processed: 9929852
# Entries Processed: 9930852
# Entries Processed: 9931852
# Entries Processed: 9932852
# Entries Processed: 9933852
# Entries Processed: 9934852
# Entries Processed: 9935852
# Entries Processed: 9936852
# Entries Processed: 9937852
# Entries Processed: 9938852
# Entries Processed: 9939852
# Entries Processed: 9940852
# Entries Processed: 9941852
# Entries Processed: 9942852
# Entries Processed: 9943852
# Entries Processed: 9944852
# Entries Processed: 9945852
# Entries Processed: 9946852
# Entries Processed: 9947852
# Entries Processed: 9948852
# Entries Processed: 9949852
# Entries Processed: 9950852
# Entries Processed: 9951852
# Entries Processed: 9952852
# Entries Processed: 9953852
# Entries Processed: 9954852
# Entries Processed: 9955852
# Entries Processed: 9956852
# Entries Processed: 9957852
# Entries Processed: 9958852
# Entries Processed: 9959852
# Entries Processed: 9960852
# Entries Processed: 9961852
# Entries Processed: 9962852
# Entries Processed: 9963852
# Entries Processed: 9964852
# Entries Processed: 9965852
# Entries Processed: 9966852
# Entries Processed: 9967852
# Entries Processed: 9968852
# Entries Processed: 9969852
# Entries Processed: 9970852
# Entries Processed: 9971852
# Entries Processed: 9972852
# Entries Processed: 9973852
# Entries Processed: 9974852
# Entries Processed: 9975852
# Entries Processed: 9976852
# Entries Processed: 9977852
# Entries Processed: 9978852
# Entries Processed: 9979852
# Entries Processed: 9980852
# Entries Processed: 9981852
# Entries Processed: 9982852
# Entries Processed: 9983852
# Entries Processed: 9984852
# Entries Processed: 9985852
# Entries Processed: 9986852
# Entries Processed: 9987852
# Entries Processed: 9988852
# Entries Processed: 9989852
# Entries Processed: 9990852
# Entries Processed: 9991852
# Entries Processed: 9992852
# Entries Processed: 9993852
# Entries Processed: 9994852
# Entries Processed: 9995852
# Entries Processed: 9996852
# Entries Processed: 9997852
# Entries Processed: 9998852
# Entries Processed: 9999852
# Entries Processed: 10000852
# Entries Processed: 10001852
# Entries Processed: 10002852
# Entries Processed: 10003852
# Entries Processed: 10004852
# Entries Processed: 10005852
# Entries Processed: 10006852
# Entries Processed: 10007852
# Entries Processed: 10008852
# Entries Processed: 10009852
# Entries Processed: 10010852
# Entries Processed: 10011852
# Entries Processed: 10012852
# Entries Processed: 10013852
# Entries Processed: 10014852
# Entries Processed: 10015852
# Entries Processed: 10016852
# Entries Processed: 10017852
# Entries Processed: 10018852
# Entries Processed: 10019852
# Entries Processed: 10020852
# Entries Processed: 10021852
# Entries Processed: 10022852
# Entries Processed: 10023852
# Entries Processed: 10024852
# Entries Processed: 10025852
# Entries Processed: 10026852
# Entries Processed: 10027852
# Entries Processed: 10028852
# Entries Processed: 10029852
# Entries Processed: 10030852
# Entries Processed: 10031852
# Entries Processed: 10032852
# Entries Processed: 10033852
# Entries Processed: 10034852
# Entries Processed: 10035852
# Entries Processed: 10036852
# Entries Processed: 10037852
# Entries Processed: 10038852
# Entries Processed: 10039852
# Entries Processed: 10040852
# Entries Processed: 10041852
# Entries Processed: 10042852
# Entries Processed: 10043852
# Entries Processed: 10044852
# Entries Processed: 10045852
# Entries Processed: 10046852
# Entries Processed: 10047852
# Entries Processed: 10048852
# Entries Processed: 10049852
# Entries Processed: 10050852
# Entries Processed: 10051852
# Entries Processed: 10052852
# Entries Processed: 10053852
# Entries Processed: 10054852
# Entries Processed: 10055852
# Entries Processed: 10056852
# Entries Processed: 10057852
# Entries Processed: 10058852
# Entries Processed: 10059852
# Entries Processed: 10060852
# Entries Processed: 10061852
# Entries Processed: 10062852
# Entries Processed: 10063852
# Entries Processed: 10064852
# Entries Processed: 10065852
# Entries Processed: 10066852
# Entries Processed: 10067852
# Entries Processed: 10068852
# Entries Processed: 10069852
# Entries Processed: 10070852
# Entries Processed: 10071852
# Entries Processed: 10072852
# Entries Processed: 10073852
# Entries Processed: 10074852
# Entries Processed: 10075852
# Entries Processed: 10076852
# Entries Processed: 10077852
# Entries Processed: 10078852
# Entries Processed: 10079852
# Entries Processed: 10080852
# Entries Processed: 10081852
# Entries Processed: 10082852
# Entries Processed: 10083852
# Entries Processed: 10084852
# Entries Processed: 10085852
# Entries Processed: 10086852
# Entries Processed: 10087852
# Entries Processed: 10088852
# Entries Processed: 10089852
# Entries Processed: 10090852
# Entries Processed: 10091852
# Entries Processed: 10092852
# Entries Processed: 10093852
# Entries Processed: 10095212
# Entries Processed: 10096212
# Entries Processed: 10097178
# Scraping for data/binance/AE-BNB-1m-2000-01-01T00-00-00Z-10097178.csv succeeded.
# Downloading price history for AE/BTC on exchange binance.
# 946684800000 10097178 60000
# Batch Size: 1000
# Total Entries: 10097178
# Note: Entries will not exist if they predate exchange history.
# Entries Processed: 9525008
# Entries Processed: 9526023
# Entries Processed: 9527023
# Entries Processed: 9649058
# Entries Processed: 9650058
# Entries Processed: 9651058
# Entries Processed: 9652058
# Entries Processed: 9653058
# Entries Processed: 9654058
# Entries Processed: 9655058
# Entries Processed: 9656058
# Entries Processed: 9657058
# Entries Processed: 9658058
# Entries Processed: 9659058
# Entries Processed: 9660058
# Entries Processed: 9661058
# Entries Processed: 9662058
# Entries Processed: 9663058
# Entries Processed: 9664058
# Entries Processed: 9665058
# Entries Processed: 9666058
# Entries Processed: 9667058
# Entries Processed: 9668058
# Entries Processed: 9669058
# Entries Processed: 9670058
# Entries Processed: 9671058
# Entries Processed: 9672058
# Entries Processed: 9673058
# Entries Processed: 9674058
# Entries Processed: 9675058
# Entries Processed: 9676058
# Entries Processed: 9677058
# Entries Processed: 9678058
# Entries Processed: 9679058
# Entries Processed: 9680058
# Entries Processed: 9681058
# Entries Processed: 9682058
# Entries Processed: 9683058
# Entries Processed: 9684058
# Entries Processed: 9685058
# Entries Processed: 9686058
# Entries Processed: 9687058
# Entries Processed: 9688058
# Entries Processed: 9689058
# Entries Processed: 9690058
# Entries Processed: 9691058
# Entries Processed: 9692058
# Entries Processed: 9693058
# Entries Processed: 9694058
# Entries Processed: 9695058
# Entries Processed: 9696058
# Entries Processed: 9697058
# Entries Processed: 9698058
# Entries Processed: 9699058
# Entries Processed: 9700058
# Entries Processed: 9701058
# Entries Processed: 9702058
# Entries Processed: 9703058
# Entries Processed: 9704058
# Entries Processed: 9705058
# Entries Processed: 9706058
# Entries Processed: 9707058
# Entries Processed: 9708058
# Entries Processed: 9709058
# Entries Processed: 9710058
# Entries Processed: 9711058
# Entries Processed: 9712058
# Entries Processed: 9713058
# Entries Processed: 9714058
# Entries Processed: 9715058
# Entries Processed: 9716058
# Entries Processed: 9717058
# Entries Processed: 9718058
# Entries Processed: 9719058
# Entries Processed: 9720058
# Entries Processed: 9721058
# Entries Processed: 9722658
# Entries Processed: 9723658
# Entries Processed: 9724763
# Entries Processed: 9725763
# Entries Processed: 9726763
# Entries Processed: 9727763
# Entries Processed: 9728763
# Entries Processed: 9729763
# Entries Processed: 9730763
# Entries Processed: 9731763
# Entries Processed: 9732763
# Entries Processed: 9734220
# Entries Processed: 9735220
# Entries Processed: 9736220
# Entries Processed: 9737220
# Entries Processed: 9738220
# Entries Processed: 9739220
# Entries Processed: 9740220
# Entries Processed: 9741220
# Entries Processed: 9742220
# Entries Processed: 9743220
# Entries Processed: 9744220
# Entries Processed: 9745220
# Entries Processed: 9746220
# Entries Processed: 9747220
# Entries Processed: 9748220
# Entries Processed: 9749220
# Entries Processed: 9750220
# Entries Processed: 9751220
# Entries Processed: 9752220
# Entries Processed: 9753220
# Entries Processed: 9754220
# Entries Processed: 9755220
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/ubuntu/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# WantReadError                             Traceback (most recent call last)
# /home/ubuntu/.local/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     293         try:
# --> 294             return self.connection.recv_into(*args, **kwargs)
#     295         except OpenSSL.SSL.SysCallError as e:
#
# /usr/lib/python3/dist-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1716             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1717         self._raise_ssl_error(self._ssl, result)
#    1718
#
# /usr/lib/python3/dist-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1522         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1523             raise WantReadError()
#    1524         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-d979eb9e2292> in <module>()
# ----> 1 populator.grab_all_pairs(data_dir, exchanges, tick_size)
#
# /home/ubuntu/quant/backtest/populator.py in grab_all_pairs(data_dir, exchanges, tick_size)
#     142         populate(data_dir, [(exchange_id, batch_size_max)], good_symbols, tick_size, '2000-01-01T00:00:00Z')
#
# /home/ubuntu/quant/backtest/populator.py in populate(data_dir, exchanges, pairs, tick_size, start, num_ticks)
#     133                                 pair, tick_size, start_ms, num_ticks, batch_size_max)
#     134
# --> 135 def grab_all_pairs(data_dir, exchanges, tick_size):
#     136     for (exchange_id, batch_size_max) in exchanges:
#     137         exchange = getattr(ccxt, exchange_id)({
#
# /home/ubuntu/quant/backtest/populator.py in scrape_ohlcv_to_csv(filename, max_retries, exchange, symbol, tick_size, start_ms, num_ticks, batch_size_max)
#      76                                        tick_size, start_ms, num_ticks, batch_size_max)
#      77         write_csv(filename, ohlcv_generator)
# ---> 78         print('Scraping for {} succeeded.'.format(filename))
#      79     except RetryError:
#      80         print('Scraping for {} failed.'.format(filename))
#
# /home/ubuntu/quant/backtest/populator.py in write_csv(filename, generator)
#      67                          'low', 'close', 'volume'])
#      68         for data in generator:
# ---> 69             writer.writerows(data)
#      70
#      71
#
# /home/ubuntu/quant/backtest/populator.py in scrape_ohlcv(max_retries, exchange, symbol, tick_size, start_ms, num_ticks, batch_size_max)
#      47         ohlcv = [row for row in retry_fetch_ohlcv(
#      48             max_retries, exchange, symbol, tick_size, position_ms, batch_size) if row[0] < end]
# ---> 49         if len(ohlcv) == 0:
#      50             print(
#      51                 'Warning: Exchange returned zero entries prior to end time. See note?')
#
# /home/ubuntu/quant/backtest/populator.py in retry_fetch_ohlcv(max_retries, exchange, symbol, tick_size_ms, position_ms, batch_size)
#      26     for _ in range(max_retries):
#      27         ohlcv = exchange.fetch_ohlcv(
# ---> 28             symbol, tick_size_ms, position_ms, batch_size)
#      29         if ohlcv is not None:
#      30             return ohlcv
#
# /home/ubuntu/.local/lib/python3.6/site-packages/ccxt/binance.py in fetch_ohlcv(self, symbol, timeframe, since, limit, params)
#     518         if limit is not None:
#     519             request['limit'] = limit  # default == max == 500
# --> 520         response = self.publicGetKlines(self.extend(request, params))
#     521         return self.parse_ohlcvs(response, market, timeframe, since, limit)
#     522
#
# /home/ubuntu/.local/lib/python3.6/site-packages/ccxt/base/exchange.py in inner(_self, params)
#     386                             if params is not None:
#     387                                 inner_kwargs['params'] = params
# --> 388                             return entry(_self, **inner_kwargs)
#     389                         return inner
#     390                     to_bind = partialer()
#
# /home/ubuntu/.local/lib/python3.6/site-packages/ccxt/binance.py in request(self, path, api, method, params, headers, body)
#    1225
#    1226     def request(self, path, api='public', method='GET', params={}, headers=None, body=None):
# -> 1227         response = self.fetch2(path, api, method, params, headers, body)
#    1228         # a workaround for {"code":-2015,"msg":"Invalid API-key, IP, or permissions for action."}
#    1229         if (api == 'private') or (api == 'wapi'):
#
# /home/ubuntu/.local/lib/python3.6/site-packages/ccxt/base/exchange.py in fetch2(self, path, api, method, params, headers, body)
#     411         self.lastRestRequestTimestamp = self.milliseconds()
#     412         request = self.sign(path, api, method, params, headers, body)
# --> 413         return self.fetch(request['url'], request['method'], request['headers'], request['body'])
#     414
#     415     def request(self, path, api='public', method='GET', params={}, headers=None, body=None):
#
# /home/ubuntu/.local/lib/python3.6/site-packages/ccxt/base/exchange.py in fetch(self, url, method, headers, body)
#     476                 headers=request_headers,
#     477                 timeout=int(self.timeout / 1000),
# --> 478                 proxies=self.proxies
#     479             )
#     480             http_response = response.text
#
# /home/ubuntu/.local/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /home/ubuntu/.local/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /home/ubuntu/.local/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /home/ubuntu/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /home/ubuntu/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# /usr/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# /usr/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /usr/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /usr/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /home/ubuntu/.local/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     304                 raise
#     305         except OpenSSL.SSL.WantReadError:
# --> 306             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     307                 raise timeout('The read operation timed out')
#     308             else:
#
# /home/ubuntu/.local/lib/python3.6/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     141     Returns True if the socket is readable, or False if the timeout expired.
#     142     """
# --> 143     return wait_for_socket(sock, read=True, timeout=timeout)
#     144
#     145
#
# /home/ubuntu/.local/lib/python3.6/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     102         return poll_obj.poll(t)
#     103
# --> 104     return bool(_retry_on_intr(do_poll, timeout))
#     105
#     106
#
# /home/ubuntu/.local/lib/python3.6/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      40     # Modern Python, that retries syscalls by default
#      41     def _retry_on_intr(fn, timeout):
# ---> 42         return fn(timeout)
#      43 else:
#      44     # Old and broken Pythons.
#
# /home/ubuntu/.local/lib/python3.6/site-packages/urllib3/util/wait.py in do_poll(t)
#     100         if t is not None:
#     101             t *= 1000
# --> 102         return poll_obj.poll(t)
#     103
#     104     return bool(_retry_on_intr(do_poll, timeout))
#
# KeyboardInterrupt:
