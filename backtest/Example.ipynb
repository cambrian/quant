# %%
# Ignore this cell if you have these installed.
# !pip3 install ccxt
# !pip3 install pandas
# !pip3 install backtrader

# %%
import importlib
importlib.reload(populator)
# Out:
# <module 'populator' from '/Users/sanjay/Workspace/Repos/quant/backtest/populator.py'>

# %%
import populator

# %%
data_dir = 'data'
exchanges = ['binance', 'bitmex']
pairs = ['BTC/USDT', 'ETH/USDT', 'BTC/USD', 'ETH/USD']
tick_size = '1m'
start = '2019-03-01T00:00:00Z'
num_ticks = 12 * 60

# %%
populator.populate(data_dir, exchanges, pairs, tick_size, start, num_ticks)
# Out:
# Downloading price history for BTC/USDT on exchange binance.
# Scraping for data/binance/BTC-USDT-1m-2019-03-01T00:00:00Z-720.csv succeeded.
# Downloading price history for ETH/USDT on exchange binance.
# Scraping for data/binance/ETH-USDT-1m-2019-03-01T00:00:00Z-720.csv succeeded.
# Exchange binance does not trade BTC/USD.
# Exchange binance does not trade ETH/USD.
# Exchange bitmex does not trade BTC/USDT.
# Exchange bitmex does not trade ETH/USDT.
# Downloading price history for BTC/USD on exchange bitmex.
# Scraping for data/bitmex/BTC-USD-1m-2019-03-01T00:00:00Z-720.csv succeeded.
# Downloading price history for ETH/USD on exchange bitmex.
# Scraping for data/bitmex/ETH-USD-1m-2019-03-01T00:00:00Z-720.csv succeeded.

# %%
import pandas

# %%
btc_usdt_path = populator.get_data_path(data_dir, 'binance', 'BTC/USDT', tick_size, start, num_ticks)
btc_usdt_frame = pandas.read_csv(btc_usdt_path, parse_dates=True)

# %%
btc_usdt_frame
# Out:
#          timestamp        o        h        l        c          v
# 0    1551398400000  3814.26  3814.50  3813.55  3814.33   9.309766
# 1    1551398460000  3814.33  3816.10  3813.26  3813.26  10.742571
# 2    1551398520000  3813.27  3816.18  3813.27  3814.52   8.627309
# 3    1551398580000  3814.93  3816.09  3813.01  3813.79   6.399509
# 4    1551398640000  3813.79  3816.23  3813.79  3816.17  11.119592
# 5    1551398700000  3816.14  3817.43  3814.26  3817.41   8.463181
# 6    1551398760000  3817.41  3817.43  3815.90  3817.11   5.549394
# 7    1551398820000  3817.10  3818.36  3817.01  3818.36   8.523976
# 8    1551398880000  3818.39  3818.68  3817.62  3818.49   9.850006
# 9    1551398940000  3818.35  3819.91  3818.02  3819.32  11.963618
# 10   1551399000000  3819.32  3820.00  3818.96  3819.53   8.896124
# 11   1551399060000  3819.53  3820.00  3819.51  3819.77   6.756257
# 12   1551399120000  3819.99  3820.00  3819.51  3820.00   4.533350
# 13   1551399180000  3819.87  3820.00  3818.96  3819.89   3.664593
# 14   1551399240000  3819.29  3819.70  3813.95  3819.70  56.696535
# 15   1551399300000  3819.52  3819.91  3819.47  3819.91  10.317414
# 16   1551399360000  3819.48  3820.01  3819.47  3819.99   9.985921
# 17   1551399420000  3819.79  3821.05  3819.63  3820.70   4.827066
# 18   1551399480000  3820.67  3820.76  3819.70  3820.54   8.807863
